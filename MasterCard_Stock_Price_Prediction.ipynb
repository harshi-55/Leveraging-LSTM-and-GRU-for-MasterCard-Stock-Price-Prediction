# %% [markdown]
# # RNN

# %%
# Importing the libraries
import warnings
warnings.filterwarnings('ignore')
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
from tensorflow.random import set_seed


#set seeds for reproducibility.
#A random seed is used to ensure that results are reproducible. In other words, using this parameter makes sure that anyone who re-runs your code will get the exact same outputs.
#Reproducibility is an extremely important concept in data science and other fields.
set_seed(455)
np.random.seed(455)

# %% [markdown]
# ## Data Analysis

# %%
dataset = pd.read_csv("Mastercard_stock_history.csv", index_col="Date", parse_dates=["Date"]).drop(["Dividends", "Stock Splits"], axis=1)
print(dataset.head())
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2006-05-25  3.748967  4.283869  3.739664  4.279217  395343000
# 2006-05-26  4.307126  4.348058  4.103398  4.179680  103044000
# 2006-05-30  4.183400  4.184330  3.986184  4.093164   49898000
# 2006-05-31  4.125723  4.219679  4.125723  4.180608   30002000
# 2006-06-01  4.179678  4.474572  4.176887  4.419686   62344000

# %%
print(dataset.describe())
# Out:
#               Open         High          Low        Close        Volume
# count  3872.000000  3872.000000  3872.000000  3872.000000  3.872000e+03
# mean    104.896814   105.956054   103.769349   104.882714  1.232250e+07
# std     106.245511   107.303589   105.050064   106.168693  1.759665e+07
# min       3.748967     4.102467     3.739664     4.083861  6.411000e+05
# 25%      22.347203    22.637997    22.034458    22.300391  3.529475e+06
# 50%      70.810079    71.375896    70.224002    70.856083  5.891750e+06
# 75%     147.688448   148.645373   146.822013   147.688438  1.319775e+07
# max     392.653890   400.521479   389.747812   394.685730  3.953430e+08

# %% [markdown]
# The minimum stock price is 4.10, and the heighst is 400.5. The means is at 105.9 and the standard deviation 107.3, which means that stocks have high varience.

# %%
dataset.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# The dataset has no missing values.

# %%
tstart = 2016
tend = 2020

def train_test_plot(dataset, tstart, tend):
    dataset.loc[f"{tstart}":f"{tend}", "High"].plot(figsize=(16, 4), legend=True)
    dataset.loc[f"{tend+1}":, "High"].plot(figsize=(16, 4), legend=True)
    plt.legend([f"Train (Before {tend+1})", f"Test ({tend+1} and beyond)"])
    plt.title("MasterCard stock price")
    plt.show()

train_test_plot(dataset,tstart,tend)

# %% [markdown]
# MasterCard stock prices have been on the rise since 2016. It had a dip in the first quarter of 2020 but it gained a stable position in the latter half of the year. Our test dataset consists of one year, from 2021 to 2022, and the rest of the dataset is used for training.

# %% [markdown]
# ## Data Preprocessing

# %%
def train_test_split(dataset, tstart, tend):
    train = dataset.loc[f"{tstart}":f"{tend}", "High"].values
    test = dataset.loc[f"{tend+1}":, "High"].values
    return train, test

training_set, test_set = train_test_split(dataset, tstart, tend)

# %%
training_set.shape
# Out:
# (1259,)

# %%
training_set.reshape(-1, 1).shape
# Out:
# (1259, 1)

# %%
sc = MinMaxScaler(feature_range=(0, 1))
training_set = training_set.reshape(-1, 1)
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
# We will use the MinMaxScaler function to standardize our training set, which will help us avoid the outliers or anomalies. You can also try using StandardScaler or any other scalar function to normalize your data and improve model performance.

# %% [markdown]
# The split_sequence function uses a training dataset and converts it into inputs (X_train) and outputs (y_train).

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


n_steps = 60
features = 1
# split into samples
X_train, y_train = split_sequence(training_set_scaled, n_steps)

# %% [markdown]
# In this project, we are using 60 n_steps. We can also reduce or increase the number of steps to optimize model performance.

# %% [markdown]
# We are working with univariate series, so the number of features is one, and we need to reshape the X_train to fit on the LSTM model. The X_train has [samples, timesteps], and we will reshape it to [samples, timesteps, features].

# %%
# Reshaping X_train for model
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],features)

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# The model consists of a single hidden layer of LSTM and an output layer. You can experiment with the number of units, as more units will give you better results. For this experiment, we will set LSTM units to 125, tanh as activation, and set input size.
#
# Finally, we will compile the model with an RMSprop optimizer and mean square error as a loss function.

# %%
# The LSTM architecture
model_lstm = Sequential()
model_lstm.add(LSTM(units=125, activation="tanh", input_shape=(n_steps, features)))
model_lstm.add(Dense(units=1))
# Compiling the model
model_lstm.compile(optimizer="RMSprop", loss="mse")

model_lstm.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 125)                 │          63,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             126 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,626 (248.54 KB)
#  Trainable params: 63,626 (248.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The model will train on 50 epochs with 32 batch sizes. You can change the hyperparameters to reduce training time or improve the results. The model training was successfully completed with the best possible loss.

# %%
model_lstm.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - loss: 0.0349
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0028
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.0017
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0011
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 9.1557e-04
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 8.7468e-04
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 8.3198e-04
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 7.8136e-04
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 7.1978e-04
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 6.5059e-04
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 7.2587e-04
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 6.3546e-04
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 6.2988e-04
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 5.8686e-04
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 5.6614e-04
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 5.4033e-04
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 5.2122e-04
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 5.0525e-04
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.9236e-04
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 4.8106e-04
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - loss: 4.7004e-04
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.5700e-04
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.5003e-04
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 4.7068e-04
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 5.0427e-04
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 5.1771e-04
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 5.1211e-04
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 5.0712e-04
# Epoch 29/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 5.0195e-04
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.9664e-04
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 4.9127e-04
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 4.8590e-04
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.8056e-04
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.7528e-04
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 4.7008e-04
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.6498e-04
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 4.5999e-04
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 4.5510e-04
# Epoch 39/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.5033e-04
# Epoch 40/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 4.4567e-04
# Epoch 41/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 4.4113e-04
# Epoch 42/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.3671e-04
# Epoch 43/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.3239e-04
# Epoch 44/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.2819e-04
# Epoch 45/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.2409e-04
# Epoch 46/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.2010e-04
# Epoch 47/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 4.1621e-04
# Epoch 48/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 4.1241e-04
# Epoch 49/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.0872e-04
# Epoch 50/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.0512e-04

# %% [markdown]
# ## Results

# %% [markdown]
# We are going to repeat preprocessing and normalize the test set. First of all we will transform then split the dataset into samples, reshape it, predict, and inverse transform the predictions into standard form.

# %%
dataset_total = dataset.loc[:,"High"]
inputs = dataset_total[len(dataset_total) - len(test_set) - n_steps :].values
inputs = inputs.reshape(-1, 1)
#scaling
inputs = sc.transform(inputs)

# Split into samples
X_test, y_test = split_sequence(inputs, n_steps)
# reshape
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], features)
#prediction
predicted_stock_price = model_lstm.predict(X_test)
#inverse transform the values
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %% [markdown]
# The plot_predictions function will plot a real versus predicted line chart. This will help us visualize the difference between actual and predicted values.
#
# The return_rmse function takes in test and predicted arguments and prints out the root mean square error (rmse) metric.

# %%
def plot_predictions(test, predicted):
    plt.plot(test, color="gray", label="Real")
    plt.plot(predicted, color="red", label="Predicted")
    plt.title("MasterCard Stock Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("MasterCard Stock Price")
    plt.legend()
    plt.show()


def return_rmse(test, predicted):
    rmse = np.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {:.2f}.".format(rmse))

# %% [markdown]
# According to the line plot below, the single-layered LSTM model has performed well.

# %%
plot_predictions(test_set,predicted_stock_price)

# %%
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 7.35.

# %% [markdown]
# ## GRU Model

# %%
model_gru = Sequential()
model_gru.add(GRU(units=125, activation="tanh", input_shape=(n_steps, features)))
model_gru.add(Dense(units=1))
# Compiling the RNN
model_gru.compile(optimizer="RMSprop", loss="mse")

model_gru.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 125)                 │          48,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             126 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 48,126 (187.99 KB)
#  Trainable params: 48,126 (187.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The model has successfully trained with 50 epochs and a batch size of 32.

# %%
model_gru.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0444
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0025
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0013
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0011
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 9.2621e-04
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 9.2475e-04
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - loss: 9.4340e-04
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 7.1019e-04
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 8.2063e-04
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 7.7094e-04
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 7.2169e-04
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 6.8405e-04
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 6.4315e-04
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 6.9230e-04
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 6.0378e-04
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 6.6313e-04
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 5.6071e-04
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 6.4079e-04
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 5.4080e-04
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 6.0954e-04
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 4.9305e-04
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 5.9382e-04
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 4.9229e-04
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 5.7252e-04
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 4.8215e-04
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 5.5254e-04
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 4.7683e-04
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 5.3006e-04
# Epoch 29/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 4.8415e-04
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 5.0846e-04
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 4.8532e-04
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 4.9229e-04
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 4.7799e-04
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.7901e-04
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - loss: 4.6914e-04
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 4.6751e-04
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 4.6021e-04
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 4.5731e-04
# Epoch 39/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.5157e-04
# Epoch 40/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 4.4812e-04
# Epoch 41/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 4.4335e-04
# Epoch 42/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.3974e-04
# Epoch 43/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 4.3559e-04
# Epoch 44/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - loss: 4.3202e-04
# Epoch 45/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - loss: 4.2828e-04
# Epoch 46/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 4.2485e-04
# Epoch 47/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 4.2142e-04
# Epoch 48/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 4.1816e-04
# Epoch 49/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.1496e-04
# Epoch 50/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 4.1188e-04

# %%
GRU_predicted_stock_price = model_gru.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
plot_predictions(test_set, GRU_predicted_stock_price)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step

# %% [markdown]
# As we can see, the real and predicted values are relatively close. The predicted line chart almost fits the actual values.

# %%
return_rmse(test_set,GRU_predicted_stock_price)
# Out:
# The root mean squared error is 5.87.

# %% [markdown]
# GRU model got 5.87 rmse on the test dataset, which is an improvement from the LSTM model.
